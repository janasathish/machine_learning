# %%
import tflearn
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.estimator import regression
import tflearn.datasets.mnist as mnist

X, Y, test_x, test_y = mnist.load_data(one_hot=True)

X = X.reshape([-1, 28, 28, 1])
test_x = test_x.reshape([-1, 28, 28, 1])

# Building convolutional convnet
convnet = input_data(shape=[None, 28, 28, 1], name='input')
# http://tflearn.org/layers/conv/
# http://tflearn.org/activations/
convnet = conv_2d(convnet, 32, 2, activation='relu')
convnet = max_pool_2d(convnet, 2)

convnet = conv_2d(convnet, 64, 2, activation='relu')
convnet = max_pool_2d(convnet, 2)

convnet = fully_connected(convnet, 1024, activation='relu')
convnet = dropout(convnet, 0.8)

convnet = fully_connected(convnet, 10, activation='softmax')
convnet = regression(convnet, optimizer='adam', learning_rate=0.01, loss='categorical_crossentropy', name='targets')

model = tflearn.DNN(convnet)
model.load('quicktest.model')
# Out:
# Extracting mnist/train-images-idx3-ubyte.gz
# /Users/administrator/anaconda/lib/python3.5/gzip.py:274: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   return self._buffer.read(size)
# /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/datasets/mnist.py:52: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   data = data.reshape(num_images, rows, cols, 1)
# Extracting mnist/train-labels-idx1-ubyte.gz
# Extracting mnist/t10k-images-idx3-ubyte.gz
# Extracting mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:766 in create_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:766 in create_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:766 in create_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/summaries.py:46 in get_summary.: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:766 in create_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:766 in create_summaries.: merge_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.merge.
# WARNING:tensorflow:VARIABLES collection name is deprecated, please use GLOBAL_VARIABLES instead; VARIABLES will be removed after 2017-03-02.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:130 in __init__.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:From /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py:378 in restore.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#
# /Users/administrator/anaconda/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for quicktest.model
# 	 [[Node: save_13/RestoreV2_256 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_13/Const_0, save_13/RestoreV2_256/tensor_names, save_13/RestoreV2_256/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-28-ba72d7a99a78> in <module>()
#      27
#      28 model = tflearn.DNN(convnet)
# ---> 29 model.load('quicktest.model')
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/models/dnn.py in load(self, model_file)
#     225
#     226         """
# --> 227         self.trainer.restore(model_file)
#     228         self.session = self.trainer.session
#     229         self.predictor = Evaluator([self.net],
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py in restore(self, model_file)
#     377         self.session = tf.Session()
#     378         self.session.run(tf.initialize_all_variables())
# --> 379         self.restorer.restore(self.session, model_file)
#     380         for o in self.train_ops:
#     381             o.session = self.session
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1386       return
#    1387     sess.run(self.saver_def.restore_op_name,
# -> 1388              {self.saver_def.filename_tensor_name: save_path})
#    1389
#    1390   @staticmethod
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1032         except KeyError:
#    1033           pass
# -> 1034       raise type(e)(node_def, op, message)
#    1035
#    1036   def _extend_graph(self):
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for quicktest.model
# 	 [[Node: save_13/RestoreV2_256 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_13/Const_0, save_13/RestoreV2_256/tensor_names, save_13/RestoreV2_256/shape_and_slices)]]
#
# Caused by op 'save_13/RestoreV2_256', defined at:
#   File "/Users/administrator/anaconda/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/administrator/anaconda/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-28-ba72d7a99a78>", line 28, in <module>
#     model = tflearn.DNN(convnet)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/models/dnn.py", line 57, in __init__
#     session=session)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tflearn/helpers/trainer.py", line 125, in __init__
#     keep_checkpoint_every_n_hours=keep_checkpoint_every_n_hours)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1000, in __init__
#     self.build()
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1030, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 624, in build
#     restore_sequentially, reshape)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 361, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 200, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 441, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 759, in apply_op
#     op_def=op_def)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2240, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/administrator/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1128, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Unsuccessful TensorSliceReader constructor: Failed to find any matching files for quicktest.model
# 	 [[Node: save_13/RestoreV2_256 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_13/Const_0, save_13/RestoreV2_256/tensor_names, save_13/RestoreV2_256/shape_and_slices)]]
